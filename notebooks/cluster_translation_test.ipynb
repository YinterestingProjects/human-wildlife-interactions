# %% [markdown]
# <a href="https://colab.research.google.com/github/YinterestingProjects/human-wildlife-interactions/blob/main/notebooks/cluster_translation_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install pandas==1.4.2
! pip install fasttext
! pip install transformers
! pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pandas==1.4.2
#   Downloading pandas-1.4.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 55.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas==1.4.2) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas==1.4.2) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas==1.4.2) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas==1.4.2) (1.15.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
# Successfully installed pandas-1.4.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 KB 10.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pybind11>=2.2
#   Using cached pybind11-2.10.3-py3-none-any.whl (222 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from fasttext) (57.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from fasttext) (1.22.4)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp39-cp39-linux_x86_64.whl size=4391756 sha256=85d1f72d462c782abc528f51bb88ffcf75095643dc4dde68f20cb5fff088dd06
#   Stored in directory: /root/.cache/pip/wheels/64/57/bc/1741406019061d5664914b070bd3e71f6244648732bc96109e
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.2 pybind11-2.10.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 103.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.1-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 24.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 106.7 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.10)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.1 tokenizers-0.13.2 transformers-4.26.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 52.8 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.97

# %%
import pickle
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '1.4.2'

# %%
# directory setup
user = "sally"
#user = "jina"
#user = "josh"
     
try:
  if user == "sally":
    directory = '/content/drive/MyDrive/MADS/MADS_Capstone'
  elif user == "jina":
    directory = "JINA: INSERT YOUR PATH HERE"
  elif user == "josh":
    directory = "/content/drive/MyDrive/MADS_Capstone"
except:
  dprint("No user has been selected")

# %%
vDets_fp = f'{directory}/data/processed/videoDets.pkl'
vComs_fp = f'{directory}/data/processed/videoComs.pkl'

with open(vDets_fp, 'rb') as f:
  vDets_df = pickle.load(f)

# %%
vDets_df.head(2)
# vDets_df.info()
# Out:
#             kind                         etag           id yt8M_id  \
# 0  youtube#video  qw6REl1mcyQq7UoW1-Dkm1yCrOY  130S1TN3P0M    HTft
# 1  youtube#video  hBay_xFV_egFO5I_5lVHS8xcSi4  iHpgw8WN6Bg    VX3C
#
#     snippet.publishedAt         snippet.channelId  \
# 0  2014-11-05T07:49:51Z  UCh_KdtEAc7qwyeXyVuuYPUA
# 1  2011-11-01T06:43:23Z  UCgBA-PogWxh44p-lKZW9EVA
#
#                                        snippet.title  \
# 0  Obserwator 22: Jesień na tamie / Autumn on  a ...
# 1    bébés ocelots et otocyons au Domaine des Fauves
#
#                                  snippet.description  \
# 0  To już pożegnanie z tamą bobrową. Jesień zawit...
# 1  les bébés ocelots âgés de 7 semaines, arrivée ...
#
#                    snippet.thumbnails.default.url  \
# 0  https://i.ytimg.com/vi/130S1TN3P0M/default.jpg
# 1  https://i.ytimg.com/vi/iHpgw8WN6Bg/default.jpg
#
#    snippet.thumbnails.default.width  ...  localizations.zh-Hans.title  \
# 0                               120  ...                          NaN
# 1                               120  ...                          NaN
#
#   localizations.zh-Hans.description  localizations.pt.title  \
# 0                               NaN                     NaN
# 1                               NaN                     NaN
#
#    localizations.pt.description localizations.zu.title  \
# 0                           NaN                    NaN
# 1                           NaN                    NaN
#
#    localizations.zu.description  localizations.af.title  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
#
#   localizations.af.description  localizations.pt-PT.title  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
#
#    localizations.pt-PT.description
# 0                              NaN
# 1                              NaN
#
# [2 rows x 87 columns]

# %%
# check if the localization worked
vDets_df['title_translated'] = np.where(vDets_df['snippet.title'] == vDets_df['snippet.localized.title'], True, False)
vDets_df['descrip_translated'] = np.where(vDets_df['snippet.description'] == vDets_df['snippet.localized.description'], True, False)

vDets_df[vDets_df['title_translated']==False] #0
vDets_df[vDets_df['descrip_translated']==False] #0

# check on field LiveBroadcastContent
vDets_df['snippet.liveBroadcastContent'].value_counts()	# all none

vDets_df['contentDetails.caption'].value_counts() # false 3818, true 77
# Out:
# false    3818
# true       77
# Name: contentDetails.caption, dtype: int64

# %%
# identify columns to use for clustering
cols_str = '''yt8M_id, id, snippet.title, snippet.description, snippet.tags'''
cols_to_keep = cols_str.split(', ')
cols_to_keep
# Out:
# ['yt8M_id', 'id', 'snippet.title', 'snippet.description', 'snippet.tags']

# %%
# sample data for testing
title_des_df = vDets_df.loc[:, cols_to_keep]
sample_df = title_des_df.sample(20, random_state=42)     # 1985 english + japanese
sample_df.head()
# Out:
#      yt8M_id           id                                snippet.title  \
# 3682    1dhU  TedONA50f8Y  富山トラウト釣行　黄金イワナ Trout fishing trip in Toyama
# 912     SyhK  MydM_86g5-8                  Fiordland NZ: Mount Titiroa
# 321     1dNW  q9c_a805j5M                         A Moment With Serena
# 2098    hUtY  xnsYaPjI0pw       Презентация-Дикие и домашние животные.
# 1480    dOax  A_qDbbb1tsI         Visite du zoo de Maubeuge 07/07/2012
#
#                                     snippet.description  \
# 3682  2011年5月2日、釣り仲間3人と富山の河川へトラウト釣行に。\r\n黄金色のイワナを釣るこ...
# 912   The Lure of Manapouri's Mt Titiroa where a gro...
# 321   She's pretty entertaining one-on-one. \n\n-- F...
# 2098  Школьные презентации "ОКРУЖАЮЩИЙ МИР"-"Дикие и...
# 1480
#
#                                            snippet.tags
# 3682  [釣り, フィッシング, 川, 本流, 渓流, トラウト, イワナ, ヤマメ, UFJ釣行,...
# 912   [Spiritual, Movie, Tourism, Spirituality, Moun...
# 321   [tiger, big cat, serena, snuffle, cute, Cat, b...
# 2098  [Презентации, слайд-шоу, окружающий мир, видео...
# 1480  [Zoo, Maubeuge, animaux, jardin, zoologique, e...

# %%
import fasttext
from transformers import pipeline
#from multilingual_translation import translation as translate
#import sentencepiece


# Load the pre-trained fasttext language detection model, translation pipeline with pre-trained model
language_detector = fasttext.load_model(f'{directory}/models/lid.176.ftz')
#translator = pipeline('translation', model='Helsinki-NLP/opus-mt-fr-en', tokenizer='Helsinki-NLP/opus-mt-fr-en')
translator = pipeline('translation', model='facebook/m2m100_418M')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# Downloading (…)lve/main/config.json:   0%|          | 0.00/908 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.94G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/233 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/272 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/3.71M [00:00<?, ?B/s]
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/1.14k [00:00<?, ?B/s]

# %%
from tqdm import tqdm
import re


def clean_text(text):
  # remove spacing
  text = text.replace('\r\n', '')
  text = text.replace('\n', '')

  # remove urls
  text = re.sub(r'http\S+', '', text)

  return text
  
  
def detect_language(text):
    '''function to detect the language of a single text string'''
    labels, scores = language_detector.predict(text)
    label = labels[0].replace("__label__", '')
    score = round(scores[0], 4)

    return label, score

def translate_text(text, source_language, target_language):
    '''function to translate a single text string from a foreign language to English'''
    if source_language == 'en':
      return text
    else:
      try: 
        results = translator(text, src_lang=source_language, tgt_lang=target_language, max_length=500)
        return results[0]['translation_text']
      except KeyError:
        return 'source language unavailable for translation'

def translate_df_column(df, column_to_translate, col_prefix):
    '''function to translate a specified column in a Pandas DataFrame from a foreign language to English'''
    
    prefix = col_prefix
    # cleaning
    df[f'{prefix}_clean'] = df[column_to_translate].apply(clean_text)
    
    # language detection
    df[f'{prefix}_src_lang'], df[f'{prefix}_src_conf'] = zip(*df[f'{prefix}_clean'].apply(detect_language))

    # english translation
    tqdm.pandas(desc=f'{prefix} translation')
    df[f'{prefix}_en'] = df.progress_apply(lambda x: translate_text(x[f'{prefix}_clean'], 
                                                                    x[f'{prefix}_src_lang'], 
                                                                    'en'
                                                                    ), axis=1)
    
    return df

# %%
#translated_df = translate_df_column(title_des_df, 'snippet.title', 'title')
#translated_df.to_pickle(f'{directory}/data/processed/translated.pkl')
with open(f'{directory}/data/processed/translated.pkl', 'rb') as translated_file:
  translated_df = pickle.load(translated_file)
translated_df.head()
# Out:
#   yt8M_id           id                                      snippet.title  \
# 0    HTft  130S1TN3P0M  Obserwator 22: Jesień na tamie / Autumn on  a ...
# 1    VX3C  iHpgw8WN6Bg    bébés ocelots et otocyons au Domaine des Fauves
# 2    j2Er  XrX9NBMUOzw   Two Giraffe Calves born at the San Francisco Zoo
# 3    3HOO  qwL5HKti-dw  Fauna salbatica bucovineana in fotografi - Buk...
# 4    6nfW  wPJy9D_kzVU  Wyoming Archery Mule Deer Hunt With Joe Thomas...
#
#                                  snippet.description  \
# 0  To już pożegnanie z tamą bobrową. Jesień zawit...
# 1  les bébés ocelots âgés de 7 semaines, arrivée ...
# 2  Follow the zoo: \r\nhttp://twitter.com/sfzoo\r...
# 3  #WildBucovina Natura si fauna sălbatică din Bu...
# 4
#
#                                         snippet.tags  \
# 0  [Łoś, Alces alces, Elk (Animal), wiewiórka, Sq...
# 1  [zoo, isère, le, domaine, des, fauves, ocelots...
# 2  [wildlife, giraffe, sfzoobehindthescenes, birt...
# 3  [Cerbi carpatini, Capriori, Deer, Landscapes.,...
# 4                                     [New, Project]
#
#                                          title_clean title_src_lang  \
# 0  Obserwator 22: Jesień na tamie / Autumn on  a ...             pl
# 1    bébés ocelots et otocyons au Domaine des Fauves             fr
# 2   Two Giraffe Calves born at the San Francisco Zoo             en
# 3  Fauna salbatica bucovineana in fotografi - Buk...             en
# 4  Wyoming Archery Mule Deer Hunt With Joe Thomas...             en
#
#    title_src_conf                                           title_en
# 0          0.3335              Observer 22: Autumn on a Beaver's Dam
# 1          0.9698      Babies and Otocyons in the Domaine des Fauves
# 2          0.9882   Two Giraffe Calves born at the San Francisco Zoo
# 3          0.2253  Fauna salbatica bucovineana in fotografi - Buk...
# 4          0.6670  Wyoming Archery Mule Deer Hunt With Joe Thomas...

# %%
desc_translated_df = translate_df_column(translated_df, 'snippet.description', 'desc')
desc_translated_df.to_pickle(f'{directory}/data/processed/desc_translated_test.pkl')
desc_translated_df.head()
# Out:
# desc translation:   1%|          | 36/3895 [07:24<13:14:01, 12.35s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-812745f9465d> in <module>
# ----> 1 desc_translated_df = translate_df_column(translated_df, 'snippet.description', 'desc')
#       2 desc_translated_df.to_pickle(f'{directory}/data/processed/desc_translated_test.pkl')
#       3 desc_translated_df.head()
#
# <ipython-input-11-f777e349c855> in translate_df_column(df, column_to_translate, col_prefix)
#      45     # english translation
#      46     tqdm.pandas(desc=f'{prefix} translation')
# ---> 47     df[f'{prefix}_en'] = df.progress_apply(lambda x: translate_text(x[f'{prefix}_clean'],
#      48                                                                     x[f'{prefix}_src_lang'],
#      49                                                                     'en'
#
# /usr/local/lib/python3.9/dist-packages/tqdm/std.py in inner(df, func, *args, **kwargs)
#     803                 # on the df using our wrapper (which provides bar updating)
#     804                 try:
# --> 805                     return getattr(df, df_function)(wrapper, **kwargs)
#     806                 finally:
#     807                     t.close()
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8837             kwargs=kwargs,
#    8838         )
# -> 8839         return op.apply().__finalize__(self, method="apply")
#    8840
#    8841     def applymap(
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/apply.py in apply(self)
#     725             return self.apply_raw()
#     726
# --> 727         return self.apply_standard()
#     728
#     729     def agg(self):
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/apply.py in apply_standard(self)
#     849
#     850     def apply_standard(self):
# --> 851         results, res_index = self.apply_series_generator()
#     852
#     853         # wrap results
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     865             for i, v in enumerate(series_gen):
#     866                 # ignore SettingWithCopy here in case the user mutates
# --> 867                 results[i] = self.f(v)
#     868                 if isinstance(results[i], ABCSeries):
#     869                     # If we have a view on v, we need to make a copy because
#
# /usr/local/lib/python3.9/dist-packages/tqdm/std.py in wrapper(*args, **kwargs)
#     798                     # take a fast or slow code path; so stop when t.total==t.n
#     799                     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 800                     return func(*args, **kwargs)
#     801
#     802                 # Apply the provided function (in **kwargs)
#
# <ipython-input-11-f777e349c855> in <lambda>(x)
#      45     # english translation
#      46     tqdm.pandas(desc=f'{prefix} translation')
# ---> 47     df[f'{prefix}_en'] = df.progress_apply(lambda x: translate_text(x[f'{prefix}_clean'],
#      48                                                                     x[f'{prefix}_src_lang'],
#      49                                                                     'en'
#
# <ipython-input-11-f777e349c855> in translate_text(text, source_language, target_language)
#      28     else:
#      29       try:
# ---> 30         results = translator(text, src_lang=source_language, tgt_lang=target_language, max_length=500)
#      31         return results[0]['translation_text']
#      32       except KeyError:
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/text2text_generation.py in __call__(self, *args, **kwargs)
#     364               token ids of the translation.
#     365         """
# --> 366         return super().__call__(*args, **kwargs)
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/text2text_generation.py in __call__(self, *args, **kwargs)
#     163         """
#     164
# --> 165         result = super().__call__(*args, **kwargs)
#     166         if (
#     167             isinstance(args[0], list)
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1082             )
#    1083         else:
# -> 1084             return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#    1085
#    1086     def run_multi(self, inputs, preprocess_params, forward_params, postprocess_params):
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py in run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1089     def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1090         model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1091         model_outputs = self.forward(model_inputs, **forward_params)
#    1092         outputs = self.postprocess(model_outputs, **postprocess_params)
#    1093         return outputs
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#     990                 with inference_context():
#     991                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# --> 992                     model_outputs = self._forward(model_inputs, **forward_params)
#     993                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#     994             else:
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/text2text_generation.py in _forward(self, model_inputs, **generate_kwargs)
#     185         generate_kwargs["max_length"] = generate_kwargs.get("max_length", self.model.config.max_length)
#     186         self.check_inputs(input_length, generate_kwargs["min_length"], generate_kwargs["max_length"])
# --> 187         output_ids = self.model.generate(**model_inputs, **generate_kwargs)
#     188         out_b = output_ids.shape[0]
#     189         if self.framework == "pt":
#
# /usr/local/lib/python3.9/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, **kwargs)
#    1472             )
#    1473             # 13. run beam search
# -> 1474             return self.beam_search(
#    1475                 input_ids,
#    1476                 beam_scorer,
#
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py in beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, **model_kwargs)
#    2720             model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2721
# -> 2722             outputs = self(
#    2723                 **model_inputs,
#    2724                 return_dict=True,
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/m2m_100/modeling_m2m_100.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1329                 )
#    1330
# -> 1331         outputs = self.model(
#    1332             input_ids,
#    1333             attention_mask=attention_mask,
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/m2m_100/modeling_m2m_100.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1220
#    1221         # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1222         decoder_outputs = self.decoder(
#    1223             input_ids=decoder_input_ids,
#    1224             attention_mask=decoder_attention_mask,
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/m2m_100/modeling_m2m_100.py in forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1082                 else:
#    1083
# -> 1084                     layer_outputs = decoder_layer(
#    1085                         hidden_states,
#    1086                         attention_mask=combined_attention_mask,
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/m2m_100/modeling_m2m_100.py in forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_value, output_attentions, use_cache)
#     501             # cross_attn cached key/values tuple is at positions 3,4 of present_key_value tuple
#     502             cross_attn_past_key_value = past_key_value[-2:] if past_key_value is not None else None
# --> 503             hidden_states, cross_attn_weights, cross_attn_present_key_value = self.encoder_attn(
#     504                 hidden_states=hidden_states,
#     505                 key_value_states=encoder_hidden_states,
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/m2m_100/modeling_m2m_100.py in forward(self, hidden_states, key_value_states, past_key_value, attention_mask, layer_head_mask, output_attentions)
#     245
#     246         # get query proj
# --> 247         query_states = self.q_proj(hidden_states) * self.scaling
#     248         # get key, value proj
#     249         # `past_key_value[0].shape[2] == key_value_states.shape[1]`
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %% [markdown]
# ### sandbox

# %%
translated_df.groupby(['title_src_lang'])['id'].count().sort_values(ascending=False)#.plot(kind='bar')
# Out:
# title_src_lang
# en    2557
# es     208
# de     177
# fr     167
# ja      91
#       ...
# az       1
# lb       1
# lv       1
# mr       1
# my       1
# Name: id, Length: 61, dtype: int64

# %%
translate_df_column(sample_df, 'snippet.title', 'title')
# Out:
# translation: 100%|██████████| 20/20 [00:36<00:00,  1.83s/it]
#      yt8M_id           id                                      snippet.title  \
# 3682    1dhU  TedONA50f8Y        富山トラウト釣行　黄金イワナ Trout fishing trip in Toyama
# 912     SyhK  MydM_86g5-8                        Fiordland NZ: Mount Titiroa
# 321     1dNW  q9c_a805j5M                               A Moment With Serena
# 2098    hUtY  xnsYaPjI0pw             Презентация-Дикие и домашние животные.
# 1480    dOax  A_qDbbb1tsI               Visite du zoo de Maubeuge 07/07/2012
# 366     CBnQ  nj0t3zi2rKY                                       Wild Animals
# 1894    NfCl  xGABQMb17nE      Country Bear and Cute Baby Cubs | BBC Studios
# 1503    HIee  GCB6KGQcmyo                                    KENYA 2011 BOOM
# 2623    9sFJ  FR5paiKmWYY          A Visit to Sydney Aquarium & Animal World
# 2992    ejaE  vV7kM-h7hsc        Cazadores por el Mundo.Territorios Salvajes
# 2392    YCKA  VXZ0uubHBwU                                       Kenia Safari
# 1657    Yc4h  mLhYCe3Y_zI                                    pups at 5 weeks
# 3882    5wna  UiPx-N9T26I  B3 T2 L6 Mating Systems & Parental Care (Audio...
# 2855    EdHt  1-RwDOysXjI                Okavango Delta Boat Safari Botswana
# 2827    qv9P  STWlFU2AOpQ  Stealth Gear One Man Photography Chair Hide Re...
# 3639    RhnM  Icxnnc9bpxs  Yorkshire Wildlife Park and  Painted Dog Conse...
# 1602    N74T  sqviQwW3Nyk      Fauna Flash: Konik paarden in de uiterwaarden
# 14      8wSl  GSv0IQtBqng  CABALLOS SALVAJES EN LAS PRADERAS DE GARABANDA...
# 1023    x73I  fQXJ5bR6O0c             Aggressive mountain gorillas in Bwindi
# 1431    0ExL  DCfZOI2wcyQ                              Epic flooding in Zion
#
#                                     snippet.description  \
# 3682  2011年5月2日、釣り仲間3人と富山の河川へトラウト釣行に。\r\n黄金色のイワナを釣るこ...
# 912   The Lure of Manapouri's Mt Titiroa where a gro...
# 321   She's pretty entertaining one-on-one. \n\n-- F...
# 2098  Школьные презентации "ОКРУЖАЮЩИЙ МИР"-"Дикие и...
# 1480
# 366   This video was shot at Vision Quest Wild Anima...
# 1894  Want more natural history and wildlife videos?...
# 1503  MASAI MARA TO BOUNCE BACK FROM CRISES...GREEN ...
# 2623  I had the opportunity to walk around these fas...
# 2992  El programa de Cazavisión Cazadores por el Mun...
# 2392          A view of the animals you see on a Safari
# 1657
# 3882  B3 Topic 2 - Behaviour In Humans and Other Ani...
# 2855  Experience the sights of nature and wildlife o...
# 2827  This is my review for the one man Photography ...
# 3639
# 1602  Look, there they are. One of the co-managers o...
# 14    EN UN PUEBLECITO DE SANTANDER. POEMA, MONTAJE,...
# 1023  Adventure Lovers is an outfitter based in Swed...
# 1431                                        description
#
#                                            snippet.tags desc_src_lang  \
# 3682  [釣り, フィッシング, 川, 本流, 渓流, トラウト, イワナ, ヤマメ, UFJ釣行,...            ja
# 912   [Spiritual, Movie, Tourism, Spirituality, Moun...            en
# 321   [tiger, big cat, serena, snuffle, cute, Cat, b...            en
# 2098  [Презентации, слайд-шоу, окружающий мир, видео...            ru
# 1480  [Zoo, Maubeuge, animaux, jardin, zoologique, e...            en
# 366   [Wild, Animals, Vision, Quest, Ranch, Bed, Bre...            en
# 1894  [country, bears, polar, cute, baby, animals, w...            en
# 1503        [KENYA, 2011, masai, mara, safari, african]            vi
# 2623  [Sydney, animals, sealife, wildlife, Australia...            en
# 2992     [rececho, gamos, venados, cazavisión, grupo v]            es
# 2392                                   [Kenia, Animals]            en
# 1657                               [pups, at, 5, weeks]            en
# 3882  [B3, Topic, Behaviour, In, Humans, Other, Anim...            en
# 2855  [okavango, delta, botswana, boat, trip, safari...            en
# 2827  [Stealth, Gear, One, Man, Photography, Chair, ...            en
# 3639  [Yorkshire Wildlife Park (Tourist Attraction),...            en
# 1602  [TVGreen, nationaal, park, natuurbeheer, envir...            nl
# 14                                                  NaN            es
# 1023  [travel, africa, african trips, mountain goril...            en
# 1431                                                NaN            en
#
#       desc_src_conf title_src_lang  title_src_conf source_lang  \
# 3682         0.8059             ja          0.5948          ja
# 912          0.9561             en          0.3247          en
# 321          0.3994             en          0.2542          en
# 2098         0.9754             ru          0.9746          ru
# 1480         0.1245             fr          0.6776          fr
# 366          0.9425             de          0.3787          de
# 1894         0.8596             en          0.6520          en
# 1503         0.6909             en          0.1245          en
# 2623         0.9907             en          0.4160          en
# 2992         0.9395             es          0.9710          es
# 2392         0.8519             en          0.1439          en
# 1657         0.1245             en          0.8959          en
# 3882         0.8559             en          0.4932          en
# 2855         0.9450             en          0.2550          en
# 2827         0.9817             en          0.8554          en
# 3639         0.1245             en          0.8981          en
# 1602         0.9908             nl          0.9124          nl
# 14           0.3058             es          0.1862          es
# 1023         0.9941             en          0.8726          en
# 1431         0.4202             en          0.8427          en
#
#       source_lang_conf                                        title_clean  \
# 3682            0.5948        富山トラウト釣行　黄金イワナ Trout fishing trip in Toyama
# 912             0.3247                        Fiordland NZ: Mount Titiroa
# 321             0.2542                               A Moment With Serena
# 2098            0.9746             Презентация-Дикие и домашние животные.
# 1480            0.6776               Visite du zoo de Maubeuge 07/07/2012
# 366             0.3787                                       Wild Animals
# 1894            0.6520      Country Bear and Cute Baby Cubs | BBC Studios
# 1503            0.1245                                    KENYA 2011 BOOM
# 2623            0.4160          A Visit to Sydney Aquarium & Animal World
# 2992            0.9710        Cazadores por el Mundo.Territorios Salvajes
# 2392            0.1439                                       Kenia Safari
# 1657            0.8959                                    pups at 5 weeks
# 3882            0.4932  B3 T2 L6 Mating Systems & Parental Care (Audio...
# 2855            0.2550                Okavango Delta Boat Safari Botswana
# 2827            0.8554  Stealth Gear One Man Photography Chair Hide Re...
# 3639            0.8981  Yorkshire Wildlife Park and  Painted Dog Conse...
# 1602            0.9124      Fauna Flash: Konik paarden in de uiterwaarden
# 14              0.1862  CABALLOS SALVAJES EN LAS PRADERAS DE GARABANDA...
# 1023            0.8726             Aggressive mountain gorillas in Bwindi
# 1431            0.8427                              Epic flooding in Zion
#
#                                                title_en
# 3682                       Trout fishing trip in Toyama
# 912                         Fiordland NZ: Mount Titiroa
# 321                                A Moment With Serena
# 2098                         Wild and domestic animals.
# 1480            Visit to the Zoo of Maubeuge 07/07/2012
# 366                                        Wild Animals
# 1894      Country Bear and Cute Baby Cubs | BBC Studios
# 1503                                    KENYA 2011 BOOM
# 2623          A Visit to Sydney Aquarium & Animal World
# 2992            Hunting for the World: Wild Territories
# 2392                                       Kenia Safari
# 1657                                    pups at 5 weeks
# 3882  B3 T2 L6 Mating Systems & Parental Care (Audio...
# 2855                Okavango Delta Boat Safari Botswana
# 2827  Stealth Gear One Man Photography Chair Hide Re...
# 3639  Yorkshire Wildlife Park and  Painted Dog Conse...
# 1602    Fauna Flash: Konik horses in the outward values
# 14    Rescue Knights in the Prades of Garabandal by ...
# 1023             Aggressive mountain gorillas in Bwindi
# 1431                              Epic flooding in Zion

# %%
sample_df.to_pickle(f'{directory}/data/processed/sample.pkl')

# %%
sample_df['snippet.title']#.apply(detect_language)
# Out:
# 3682          富山トラウト釣行　黄金イワナ Trout fishing trip in Toyama
# 912                           Fiordland NZ: Mount Titiroa
# 321                                  A Moment With Serena
# 2098               Презентация-Дикие и домашние животные.
# 1480                 Visite du zoo de Maubeuge 07/07/2012
# 366                                          Wild Animals
# 1894        Country Bear and Cute Baby Cubs | BBC Studios
# 1503                                      KENYA 2011 BOOM
# 2623            A Visit to Sydney Aquarium & Animal World
# 2992          Cazadores por el Mundo.Territorios Salvajes
# 2392                                         Kenia Safari
# 1657                                      pups at 5 weeks
# 3882    B3 T2 L6 Mating Systems & Parental Care (Audio...
# 2855                  Okavango Delta Boat Safari Botswana
# 2827    Stealth Gear One Man Photography Chair Hide Re...
# 3639    Yorkshire Wildlife Park and  Painted Dog Conse...
# 1602        Fauna Flash: Konik paarden in de uiterwaarden
# 14      CABALLOS SALVAJES EN LAS PRADERAS DE GARABANDA...
# 1023               Aggressive mountain gorillas in Bwindi
# 1431                                Epic flooding in Zion
# Name: snippet.title, dtype: object

# %%
detect_language(sample_df['snippet.title'][3682])
# Out:
# ('ja', 0.5948)

# %%
sample_df['desc_src_lang'], sample_df['desc_src_conf']= zip(*sample_df['snippet.description'].apply(detect_language))
sample_df['title_src_lang'], sample_df['title_src_conf']= zip(*sample_df['snippet.title'].apply(detect_language))
sample_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-74143375b47c> in <module>
# ----> 1 sample_df['desc_src_lang'], sample_df['desc_src_conf']= zip(*sample_df['snippet.description'].apply(detect_language))
#       2 sample_df['title_src_lang'], sample_df['title_src_conf']= zip(*sample_df['snippet.title'].apply(detect_language))
#       3 sample_df
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in apply(self)
#    1080             return self.apply_str()
#    1081
# -> 1082         return self.apply_standard()
#    1083
#    1084     def agg(self):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1135                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136                 # "Callable[[Any], Any]"
# -> 1137                 mapped = lib.map_infer(
#    1138                     values,
#    1139                     f,  # type: ignore[arg-type]
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-121-706d9dc0b386> in detect_language(text)
#      16 def detect_language(text):
#      17     '''function to detect the language of a single text string'''
# ---> 18     labels, scores = language_detector.predict(text)
#      19     label = labels[0].replace("__label__", '')
#      20     score = round(scores[0], 4)
#
# /usr/local/lib/python3.8/dist-packages/fasttext/FastText.py in predict(self, text, k, threshold, on_unicode_error)
#     223             return all_labels, all_probs
#     224         else:
# --> 225             text = check(text)
#     226             predictions = self.f.predict(text, k, threshold, on_unicode_error)
#     227             if predictions:
#
# /usr/local/lib/python3.8/dist-packages/fasttext/FastText.py in check(entry)
#     210         def check(entry):
#     211             if entry.find('\n') != -1:
# --> 212                 raise ValueError(
#     213                     "predict processes one line at a time (remove \'\\n\')"
#     214                 )
#
# ValueError: predict processes one line at a time (remove '\n')

# %%
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 3682 to 1431
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   yt8M_id              20 non-null     object
#  1   id                   20 non-null     object
#  2   snippet.title        20 non-null     object
#  3   snippet.description  20 non-null     object
#  4   snippet.tags         18 non-null     object
#  5   source_lang          20 non-null     object
#  6   source_conf          20 non-null     float64
# dtypes: float64(1), object(6)
# memory usage: 1.2+ KB

# %%
sample_df['snippet.description'][3682]
# Out:
# '2011年5月2日、釣り仲間3人と富山の河川へトラウト釣行に。\r\n黄金色のイワナを釣ることが出来ました。\r\n\r\nBegining of May 2011,\r\nAt Toyama pref. in Japan\r\nThere`s still some snow at mountain stream area,\r\nI fished golden char by chance,which is not usual.\r\n\r\nBlog:UFJ釣行 /UFJ Fishing\r\n http://ufj.naturum.ne.jp/\r\n\r\n Twitter: \r\nhttp://twitter.com/#!/Bo_Rovan'

# %%
def clean_text(text):
  # remove spacing
  text = text.replace('\r\n', '')

  # remove urls
  text = re.sub(r'http\S+', '', text)

  return text

# %%
translator(clean_text(sample_df['snippet.description'][3682]), src_lang='ja', tgt_lang ='en')
# Out:
# [{'translation_text': 'Begining of May 2011, At Toyama pref. in JapanThere`s still some snow at mountain stream area, I fished golden char by chance,which is not usual.Blog:UFJ Fishing /UFJ Fishing Twitter:'}]

# %%
translator(clean_text(sample_df['snippet.description'][2098]), src_lang='ru', tgt_lang ='en')
# Out:
# [{'translation_text': 'School presentations "Around the World"-"Wild and domestic animals." watch online movies on'}]

# %%
sample_df['snippet.description'][2098]
# Out:
# 'Школьные презентации "ОКРУЖАЮЩИЙ МИР"-"Дикие и домашние животные." http://lerusik.taba.ru/\nсмотреть онлайн фильмы на http://kinotron.ucoz.ru/'

# %%
# sample a group to test translator
test_df = translated_df.sample(20, random_state=21)
test_df.groupby(['desc_src_lang']).size()
# Out:
# desc_src_lang
# de    1
# en    8
# es    3
# fr    3
# it    1
# ja    1
# pt    1
# sh    1
# th    1
# dtype: int64

# %%
buffer = []
for lang, group in test_df.groupby(['desc_src_lang']):
  print(lang)
  print(len(group))
  #print(group['snippet.description'].to_list())
  if lang == 'en':
    buffer.append('en')
  else:
    try:
      results = translator(group['snippet.description'].to_list(), batch_size = 10, src_lang=lang, tgt_lang='en', max_length=400)
      buffer.append(results)
    except KeyError:
      buffer.append('translation not available for this language')
# Out:
# de
# 1
# en
# 8
# es
# 3
# fr
# 3
# Your input_length: 1253 is bigger than 0.9 * max_length: 400. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# it
# 1
# ja
# 1
# pt
# 1
# sh
# 1
# th
# 1

# %%
buffer[2]
# Out:
# [{'translation_text': 'One of the most beautiful national parks in Chile'},
#  {'translation_text': 'In this video you will be able to appreciate the works of the artist Alexander Cruz. All images have copyright ©.'},
#  {'translation_text': 'We visit the fabulous finca Las Alberquillas with our friends of Dehesas&Umbrias.'}]

# %%
translator(text, src_lang=source_language, tgt_lang=target_language, max_length=400)

# %%
! pip freeze > requirements.txt
