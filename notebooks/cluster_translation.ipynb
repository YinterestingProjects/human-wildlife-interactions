# %% [markdown]
# <a href="https://colab.research.google.com/github/YinterestingProjects/human-wildlife-interactions/blob/main/notebooks/cluster_translation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pandas==1.4.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pandas==1.4.2
#   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 19.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.8/dist-packages (from pandas==1.4.2) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas==1.4.2) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas==1.4.2) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.8.1->pandas==1.4.2) (1.15.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
# Successfully installed pandas-1.4.2

# %%
import pickle
import pandas as pd
pd.__version__
# Out:
# '1.4.2'

# %%
# directory setup
user = "sally"
#user = "jina"
#user = "josh"
     
try:
  if user == "sally":
    directory = '/content/drive/MyDrive/MADS/MADS_Capstone'
  elif user == "jina":
    directory = "JINA: INSERT YOUR PATH HERE"
  elif user == "josh":
    directory = "/content/drive/MyDrive/MADS_Capstone"
except:
  dprint("No user has been selected")

# %%
vDets_fp = f'{directory}/data/processed/videoDets.pkl'
vComs_fp = f'{directory}/data/processed/videoComs.pkl'

with open(vDets_fp, 'rb') as f:
  vDets_df = pickle.load(f)

# %%
vDets_df.head()
# Out:
#             kind                         etag           id yt8M_id  \
# 0  youtube#video  qw6REl1mcyQq7UoW1-Dkm1yCrOY  130S1TN3P0M    HTft
# 1  youtube#video  hBay_xFV_egFO5I_5lVHS8xcSi4  iHpgw8WN6Bg    VX3C
# 2  youtube#video  mL9iQVdY6fO5wzmPR7ubdlf2Zhw  XrX9NBMUOzw    j2Er
# 3  youtube#video  XY93dMczSpUYyP18PTAnGLAW7Ws  qwL5HKti-dw    3HOO
# 4  youtube#video  NcYca-t2DZKiXg5HhMYTuQeGBoI  wPJy9D_kzVU    6nfW
#
#     snippet.publishedAt         snippet.channelId  \
# 0  2014-11-05T07:49:51Z  UCh_KdtEAc7qwyeXyVuuYPUA
# 1  2011-11-01T06:43:23Z  UCgBA-PogWxh44p-lKZW9EVA
# 2  2006-08-05T18:57:44Z  UC4ONXuixSMf5o9O67A4gzhg
# 3  2009-12-03T14:46:09Z  UCWc9ziDlznO7v7cjzuT-Pqw
# 4  2010-07-13T06:23:18Z  UCtCCW9be1rUw_ig4UWsOSNg
#
#                                        snippet.title  \
# 0  Obserwator 22: Jesień na tamie / Autumn on  a ...
# 1    bébés ocelots et otocyons au Domaine des Fauves
# 2   Two Giraffe Calves born at the San Francisco Zoo
# 3  Fauna salbatica bucovineana in fotografi - Buk...
# 4  Wyoming Archery Mule Deer Hunt With Joe Thomas...
#
#                                  snippet.description  \
# 0  To już pożegnanie z tamą bobrową. Jesień zawit...
# 1  les bébés ocelots âgés de 7 semaines, arrivée ...
# 2  Follow the zoo: \r\nhttp://twitter.com/sfzoo\r...
# 3  #WildBucovina Natura si fauna sălbatică din Bu...
# 4
#
#                    snippet.thumbnails.default.url  \
# 0  https://i.ytimg.com/vi/130S1TN3P0M/default.jpg
# 1  https://i.ytimg.com/vi/iHpgw8WN6Bg/default.jpg
# 2  https://i.ytimg.com/vi/XrX9NBMUOzw/default.jpg
# 3  https://i.ytimg.com/vi/qwL5HKti-dw/default.jpg
# 4  https://i.ytimg.com/vi/wPJy9D_kzVU/default.jpg
#
#    snippet.thumbnails.default.width  ...  localizations.zh-Hans.title  \
# 0                               120  ...                          NaN
# 1                               120  ...                          NaN
# 2                               120  ...                          NaN
# 3                               120  ...                          NaN
# 4                               120  ...                          NaN
#
#   localizations.zh-Hans.description  localizations.pt.title  \
# 0                               NaN                     NaN
# 1                               NaN                     NaN
# 2                               NaN                     NaN
# 3                               NaN                     NaN
# 4                               NaN                     NaN
#
#    localizations.pt.description localizations.zu.title  \
# 0                           NaN                    NaN
# 1                           NaN                    NaN
# 2                           NaN                    NaN
# 3                           NaN                    NaN
# 4                           NaN                    NaN
#
#    localizations.zu.description  localizations.af.title  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
#
#   localizations.af.description  localizations.pt-PT.title  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
#    localizations.pt-PT.description
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
# [5 rows x 87 columns]
